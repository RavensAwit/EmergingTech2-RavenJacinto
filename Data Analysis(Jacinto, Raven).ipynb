# %% [markdown]
# **Name: Raven Jacinto** <br>**Course and Section: CPE019 - CPE32S3** <br>**Date of Submission: Feb. 7, 2024** <br>**Instructor: Engr. Roman Richard** <br>

# %% [markdown]
# **Objectives:**<br>
#
# **Part 1: The Dataset**
#
# **Part 2: Scatterplot Graphs and Correlatable Variables**
#
# **Part 3: Calculating Correlation with Python**
#
# **Part 4: Visualizing** </b><br>

# %% [markdown]
# Scenario/Background
# Correlation is an important statistical relationship that can indicate whether the variable values are
# linearly related.
# In this lab, you will learn how to use Python to calculate correlation. In Part 1, you will setup the dataset.
# In Part 2, you will learn how to identify if the variables in a given dataset are correlatable. Finally, in Part
# 3, you will use Python to calculate the correlation between two sets of variable.
# Required Resources
# 1 PC with Internet access
# Raspberry Pi version 2 or higher
# Python libraries: pandas, numpy, matplotlib, seaborn
# Datafiles: brainsize.txt

# %% [markdown]
# You will use a dataset that contains a sample of 40 right-handed Anglo Introductory Psychology
# students at a large Southwestern university. Subjects took four subtests (Vocabulary, Similarities, Block
# Design, and Picture Completion) of the Wechsler (1981) Adult Intelligence Scale-Revised. The
# researchers used Magnetic Resonance Imaging (MRI) to determine the brain size of the subjects.
# Information about gender and body size (height and weight) are also included. The researchers withheld
# the weights of two subjects and the height of one subject for reasons of confidentiality. Two simple
# modifications were applied to the dataset:

# %% [markdown]
# 1. Replace the quesion marks used to represent the withheld data points described above by the
# 'NaN' string. The substitution was done because Pandas does not handle the question marks
# correctly.

# %% [markdown]
# 2. Replace all tab characters with commas, converting the dataset into a CSV dataset.
# The prepared dataset is saved as brainsize.txt.
# Step 1: Loading the Dataset From a File.
# Before the dataset can be used, it must be loaded onto memory.
# In the code below, The first line imports the pandas modules and defines pd as a descriptor that refers to
# the module.
# The second line loads the dataset CSV file into a variable called brainFile.
# The third line uses read_csv(), a pandas method, to convert the CSV dataset stored in brainFile into a
# dataframe. The dataframe is then stored in the brainFrame variable.
# Run the cell below to execute the described functions.

# %%
# Code cell 1
import pandas as pd

brainFile = '/content/brainsize.txt'
brainFrame = pd.read_csv(brainFile,delim_whitespace=True)

# %% [markdown]
# Step 2: Verifying the dataframe.
# To make sure the dataframe has been correctly loaded and created, use the head() method. Another
# Pandas method, head() displays the first five entries of a dataframe

# %%
# Code cell 2
brainFrame.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0  Female   133  132  124   118.0    64.5     816932
# 1    Male   140  150  124     NaN    72.5    1001121
# 2    Male   139  123  150   143.0    73.3    1038437
# 3    Male   133  129  128   172.0    68.8     965353
# 4  Female   137  132  134   147.0    65.0     951545
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['FSIQ'].plot(kind='hist', bins=20, title='FSIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['VIQ'].plot(kind='hist', bins=20, title='VIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['PIQ'].plot(kind='hist', bins=20, title='PIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_20.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='FSIQ', y='VIQ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22.plot(kind='scatter', x='VIQ', y='PIQ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23.plot(kind='scatter', x='PIQ', y='Weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24.plot(kind='scatter', x='Weight', y='Height', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_25['FSIQ'].plot(kind='line', figsize=(8, 4), title='FSIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['VIQ'].plot(kind='line', figsize=(8, 4), title='VIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['PIQ'].plot(kind='line', figsize=(8, 4), title='PIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['Weight'].plot(kind='line', figsize=(8, 4), title='Weight')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_29['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_29, x='FSIQ', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_30['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_30, x='VIQ', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_31['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_31, x='PIQ', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_32['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_32, x='Weight', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# # **Part 2: Scatterplot Graphs and Correlatable Variables**

# %% [markdown]
# Step 1: The pandas describe() method.
# The pandas module includes the describe() method which performs same common calculations
# against a given dataset. In addition to provide common results including count, mean, standard
# deviation, minimum, and maximum, describe() is also a great way to quickly test the validity of the
# values in the dataframe.
# Run the cell below to output the results computed by describe() against the brainFrame dataframe.

# %%
# Code cell 3
brainFrame.describe()
# Out:
#              FSIQ         VIQ        PIQ      Weight     Height     MRI_Count
# count   40.000000   40.000000   40.00000   38.000000  39.000000  4.000000e+01
# mean   113.450000  112.350000  111.02500  151.052632  68.525641  9.087550e+05
# std     24.082071   23.616107   22.47105   23.478509   3.994649  7.228205e+04
# min     77.000000   71.000000   72.00000  106.000000  62.000000  7.906190e+05
# 25%     89.750000   90.000000   88.25000  135.250000  66.000000  8.559185e+05
# 50%    116.500000  113.000000  115.00000  146.500000  68.000000  9.053990e+05
# 75%    135.500000  129.750000  128.00000  172.000000  70.500000  9.500780e+05
# max    144.000000  150.000000  150.00000  192.000000  77.000000  1.079549e+06
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_33['FSIQ'].plot(kind='hist', bins=20, title='FSIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_34['VIQ'].plot(kind='hist', bins=20, title='VIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_35['PIQ'].plot(kind='hist', bins=20, title='PIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_37.plot(kind='scatter', x='FSIQ', y='VIQ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38.plot(kind='scatter', x='VIQ', y='PIQ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39.plot(kind='scatter', x='PIQ', y='Weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_40.plot(kind='scatter', x='Weight', y='Height', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_41['FSIQ'].plot(kind='line', figsize=(8, 4), title='FSIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_42['VIQ'].plot(kind='line', figsize=(8, 4), title='VIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_43['PIQ'].plot(kind='line', figsize=(8, 4), title='PIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_44['Weight'].plot(kind='line', figsize=(8, 4), title='Weight')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Step 2: Scatterplot graphs
# Scatterplot graphs are important when working with correlations as they allow for a quick visual
# verification of the nature of the relationship between the variables. This lab uses the Pearson correlation
# coefficient, which is sensitive only to a linear relationship between two variables. Other more robust
# correlation methods exist but are out of the scope of this lab.
# a. Load the required modules.
# Before graphs can be plotted, it is necessary to import a few modules, namely numpy and matplotlib.
# Run the cell below to load these modules.

# %%
# Code cell 4
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Separate the data.
# To ensure the results do not get skewed because of the differences in male and female bodies, the
# dateframe is split into two dataframes: one containing all male entries and another with only female
# instances.
# Running the cell below creates the two new dataframes, menDf and womenDf, each one containing the
# respective entries.

# %%
# Code cell 5
menDf = brainFrame[(brainFrame.Gender == 'Male')]
womenDf = brainFrame[(brainFrame.Gender == 'Female')]

# %% [markdown]
# c. Plot the graphs.
# Because the dataset includes three different measures of intelligence (PIQ, FSIQ, and VIQ), the first line
# below uses Pandas mean() method to calculate the mean value between the three and store the result in
# the menMeanSmarts variable. Notice that the first line also refers to the menDf, the filtered dataframe
# containing only male entries.
# The second line uses the matplotlib method scatter() to create a scatterplot graph between the
# menMeanSmarts variable and the MRI_Countattribute. The MRI_Count in this dataset can be thought as of
# a measure of the physical size of the subjects' brains.
# The third line simply displays the graph.
# The fourth line is used to ensure the graph will be displayed in this notebook.

# %%
# Code cell 6
menMeanSmarts = menDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(menMeanSmarts, menDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %% [markdown]
# Similarly, the code below creates a scatterplot graph for the women-only filtered dataframe

# %%
# Code cell 7
# Graph the women-only filtered dataframe
womenMeanSmarts = womenDf[["PIQ", "FSIQ", "VIQ",]].mean(axis=1)
plt.scatter(womenMeanSmarts, womenDf["MRI_Count"])
plt.show()
# %matplotlib inline

# %% [markdown]
# # **Part 3: Calculating Correlation with Python**

# %% [markdown]
# Step 1: Calculate correlation against brainFrame.
# The pandas corr() method provides an easy way to calculate correlation against a dataframe. By simply
# calling the method against a dataframe, one can get the correlation between all variables at the same
# time.

# %%
# Code cell 8
brainFrame.corr(method='pearson')
# Out:
# <ipython-input-56-cab48f3abe05>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   brainFrame.corr(method='pearson')
#             Unnamed: 0     Close    Volume      Open      High       Low
# Unnamed: 0    1.000000 -0.889680 -0.101261 -0.889586 -0.888441 -0.891092
# Close        -0.889680  1.000000  0.022835  0.998994  0.999524  0.999576
# Volume       -0.101261  0.022835  1.000000  0.027012  0.030871  0.018274
# Open         -0.889586  0.998994  0.027012  1.000000  0.999459  0.999386
# High         -0.888441  0.999524  0.030871  0.999459  1.000000  0.999251
# Low          -0.891092  0.999576  0.018274  0.999386  0.999251  1.000000

# %% [markdown]
# Notice at the left-to-right diagonal in the correlation table generated above. Why is the diagonal filled
# with 1s? Is that a coincidence? Explain.
# Still looking at the correlation table above, notice that the values are mirrored; values below the 1
# diagonal have a mirrored counterpart above the 1 diagonal. Is that a coincidence? Explain.
# Using the same corr() method, it is easy to calculate the correlation of the variables contained in the
# female-only dataframe:

# %%
# Code cell 9
womenDf.corr(method='pearson')
# Out:
# <ipython-input-37-a6271751808a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   womenDf.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.955717  0.939382  0.038192 -0.059011   0.325697
# VIQ        0.955717  1.000000  0.802652 -0.021889 -0.146453   0.254933
# PIQ        0.939382  0.802652  1.000000  0.113901 -0.001242   0.396157
# Weight     0.038192 -0.021889  0.113901  1.000000  0.552357   0.446271
# Height    -0.059011 -0.146453 -0.001242  0.552357  1.000000   0.174541
# MRI_Count  0.325697  0.254933  0.396157  0.446271  0.174541   1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_57['FSIQ'].plot(kind='hist', bins=20, title='FSIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_58['VIQ'].plot(kind='hist', bins=20, title='VIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_59['PIQ'].plot(kind='hist', bins=20, title='PIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_60['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_61.plot(kind='scatter', x='FSIQ', y='VIQ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_62.plot(kind='scatter', x='VIQ', y='PIQ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_63.plot(kind='scatter', x='PIQ', y='Weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_64.plot(kind='scatter', x='Weight', y='Height', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_65['FSIQ'].plot(kind='line', figsize=(8, 4), title='FSIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_66['VIQ'].plot(kind='line', figsize=(8, 4), title='VIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_67['PIQ'].plot(kind='line', figsize=(8, 4), title='PIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_68['Weight'].plot(kind='line', figsize=(8, 4), title='Weight')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# And the same can be done for the male-only dataframe:

# %%
# Code cell 10
# Use corr() for the male-only dataframe with the pearson method
menDf.corr(method='pearson')
# Out:
# <ipython-input-44-cc2854916971>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   menDf.corr(method='pearson')
#                FSIQ       VIQ       PIQ    Weight    Height  MRI_Count
# FSIQ       1.000000  0.944400  0.930694 -0.278140 -0.356110   0.498369
# VIQ        0.944400  1.000000  0.766021 -0.350453 -0.355588   0.413105
# PIQ        0.930694  0.766021  1.000000 -0.156863 -0.287676   0.568237
# Weight    -0.278140 -0.350453 -0.156863  1.000000  0.406542  -0.076875
# Height    -0.356110 -0.355588 -0.287676  0.406542  1.000000   0.301543
# MRI_Count  0.498369  0.413105  0.568237 -0.076875  0.301543   1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_69['FSIQ'].plot(kind='hist', bins=20, title='FSIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_70['VIQ'].plot(kind='hist', bins=20, title='VIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_71['PIQ'].plot(kind='hist', bins=20, title='PIQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_72['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_73.plot(kind='scatter', x='FSIQ', y='VIQ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_74.plot(kind='scatter', x='VIQ', y='PIQ', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_75.plot(kind='scatter', x='PIQ', y='Weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_76.plot(kind='scatter', x='Weight', y='Height', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_77['FSIQ'].plot(kind='line', figsize=(8, 4), title='FSIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_78['VIQ'].plot(kind='line', figsize=(8, 4), title='VIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_79['PIQ'].plot(kind='line', figsize=(8, 4), title='PIQ')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_80['Weight'].plot(kind='line', figsize=(8, 4), title='Weight')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # **Part 4: Visualizing**

# %% [markdown]
# Step 1: Install Seaborn.
# To make it easier to visualize the data correlations, heatmap graphs can be used. Based on colored
# squares, heatmap graphs can help identify correlations in a glance.
# The Python module named seaborn makes it very easy to plot heatmap graphs.
# First, run the cell below to download and install the seaborn module.

# %%
# Code cell 11
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %% [markdown]
# Step 2: Plot the correlation heatmap.
# Now that the dataframes are ready, the heatmaps can be plotted. Below is a breakdown of the code in the
# cell below:
# Line 1: Generates a correlation table based on the womenNoGenderDf dataframe and stores it on wcorr.
# Line 2: Uses the seaborn heatmap() method to generate and plot the heatmap. Notice that heatmap()
# takes wcorr as a parameter.
# Line 3: Use to export and save the generated heatmap as a PNG image. While the line 3 is not active (it
# has the comment # character preceding it, forcing the interpreter to ignore it), it was kept for
# informational purposes.

# %%
# Code cell 12
import seaborn as sns
wcorr = womenDf.corr()
sns.heatmap(wcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-57-2465c40f5efb>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   wcorr = womenDf.corr()
# <Axes: >

# %% [markdown]
# Similarly, the code below creates and plots a heatmap for the male-only dataframe.

# %%
# Code cell 14
mcorr = menDf.corr()
sns.heatmap(mcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-41-ff3e250059fc>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mcorr = menDf.corr()
# <Axes: >

# %% [markdown]
# ## **Many variable pairs present correlation close to zero. What does that mean?**
#
# ### - It means that there is a WEAK linear relationship between the two variables we are comparing. Because when it is exactly zero (0), it means that there is no relationship for the two variables. However, 1 and -1 shows perfect linear relationship. Therefore, close to 0 is just WEAK but still it has a linear relationship.
#
# ## **Why separate the genders?**
#
# ### - Other than it is easy to manage when it is separated, genders presented could give different values and relation to each other since they are different class of subjects. It can differ in average weight or height, etc. that may also affect the information we are trying to get and extract here in our data.
#
#
# ## **What variables have stronger correlation with brain size (MRI_Count)? Is that expected? Explain.**
#
# ### - It is not expected, I do think that there may be other correlations that it is not in scope of the data that we have.

# %% [markdown]
# # **SUPPLEMENTARY ACTIVITY**

# %% [markdown]
# ### **Loading the data set, using the data set that can be found on the open source, Kaggle.**

# %% [markdown]
# ### **HW is the dataset of height and weight of female and male person in North America**

# %%
# Code cell 1
import pandas as pd

HWFile = '/content/HW.csv'
HWFrame = pd.read_csv(HWFile)

# %% [markdown]
# ### **Load at least 50 data from my dataset**

# %%
HWFrame.head(50)
# Out:
#     Height  Weight     Sex
# 0   165.65   35.41  Female
# 1   148.53   74.45  Female
# 2   167.04   81.22    Male
# 3   161.54   71.47    Male
# 4   174.31   78.18    Male
# 5   143.05   79.27  Female
# 6   149.16   63.71  Female
# 7   155.80   86.01  Female
# 8   145.37   88.33  Female
# 9   162.56   87.36    Male
# 10  163.84   78.58    Male
# 11  172.73   88.08    Male
# 12  142.03   56.30  Female
# 13  150.17   53.46  Female
# 14  188.62   60.95    Male
# 15  184.62   72.51    Male
# 16  168.43   86.80    Male
# 17  171.19   54.12    Male
# 18  137.10   73.36  Female
# 19  149.42   69.20  Female
# 20  147.33   56.01  Female
# 21  175.14  107.25    Male
# 22  168.04   92.24    Male
# 23  158.54   64.44    Male
# 24  138.90   68.75  Female
# 25  129.27   58.43  Female
# 26  173.64   59.52  Female
# 27  175.26   62.65    Male
# 28  180.09   44.07    Male
# 29  144.58   83.36  Female
# 30  178.76   66.12    Male
# 31  151.53   91.02    Male
# 32  168.55   80.20    Male
# 33  160.86   63.68    Male
# 34  183.83   62.75    Male
# 35  179.27   50.04    Male
# 36  158.89   60.49    Male
# 37  124.37   74.57  Female
# 38  140.42   54.64  Female
# 39  155.06   84.34    Male
# 40  166.62   75.18    Male
# 41  172.96   78.39    Male
# 42  174.34   84.76    Male
# 43  165.09   83.54  Female
# 44  138.09   63.06  Female
# 45  141.31   52.13  Female
# 46  162.63   65.25    Male
# 47  178.49   73.67    Male
# 48  165.95   52.42    Male
# 49  156.92   54.45  Female
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_98['Height'].plot(kind='hist', bins=20, title='Height')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_99['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_100.groupby('Sex').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_101.plot(kind='scatter', x='Height', y='Weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_102['Height'].plot(kind='line', figsize=(8, 4), title='Height')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_103['Weight'].plot(kind='line', figsize=(8, 4), title='Weight')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_104['Sex'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_104, x='Height', y='Sex', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_105['Sex'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_105, x='Weight', y='Sex', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ## **Use the describe feature on the loaded data**

# %%
HWFrame.describe()
# Out:
#             Height       Weight
# count  3000.000000  3000.000000
# mean    161.350427    68.400610
# std      54.912719    17.041528
# min      25.680000     8.530000
# 25%     149.502500    57.937500
# 50%     160.870000    67.370000
# 75%     171.632500    77.952500
# max    3050.000000   485.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_93['Height'].plot(kind='hist', bins=20, title='Height')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_94['Weight'].plot(kind='hist', bins=20, title='Weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_95.plot(kind='scatter', x='Height', y='Weight', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_96['Height'].plot(kind='line', figsize=(8, 4), title='Height')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_97['Weight'].plot(kind='line', figsize=(8, 4), title='Weight')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ## **Separate the data using matplotlib to better understand and extract information on our data.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
maleHWDf = HWFrame[(HWFrame.Sex == 'Male')]
femaleHWDf = HWFrame[(HWFrame.Sex == 'Female')]

# %% [markdown]
# ## **In here we are getting the mean of the separated dataset and get only the male height and weight. Also, we do the same for the female subjects.**

# %%
MeanMenHeight = maleHWDf[["Height"]].mean(axis=1)
plt.scatter(MeanMenHeight, maleHWDf["Weight"])
plt.show()
# %matplotlib inline

# %%
MeanFemaleHeight = femaleHWDf[["Height"]].mean(axis=1)
plt.scatter(MeanFemaleHeight, femaleHWDf["Weight"])
plt.show()
# %matplotlib inline

# %%
brainFrame.corr(method='pearson')
# Out:
# <ipython-input-92-4d3089cc6357>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   brainFrame.corr(method='pearson')
#             Unnamed: 0     Close    Volume      Open      High       Low
# Unnamed: 0    1.000000 -0.889680 -0.101261 -0.889586 -0.888441 -0.891092
# Close        -0.889680  1.000000  0.022835  0.998994  0.999524  0.999576
# Volume       -0.101261  0.022835  1.000000  0.027012  0.030871  0.018274
# Open         -0.889586  0.998994  0.027012  1.000000  0.999459  0.999386
# High         -0.888441  0.999524  0.030871  0.999459  1.000000  0.999251
# Low          -0.891092  0.999576  0.018274  0.999386  0.999251  1.000000

# %% [markdown]
# ## **Now we are visualizing the heatmap representation of the data we have explored using seaborn and it shows the calculated heat map of the male and female height and weight in North America and shows it correlation**

# %%
import seaborn as sns
wcorr = maleHWDf.corr()
sns.heatmap(wcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-96-fd148f996af1>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   wcorr = maleHWDf.corr()
# <Axes: >

# %%
import seaborn as sns
wcorr = femaleHWDf.corr()
sns.heatmap(wcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-94-11697a872fea>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   wcorr = womenHWDf.corr()
# <Axes: >

# %%
mcorr = maleHWDf.corr()
sns.heatmap(mcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-101-fc5b53691def>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mcorr = maleHWDf.corr()
# <Axes: >

# %%
mcorr = femaleHWDf.corr()
sns.heatmap(mcorr)
#plt.savefig('attribute_correlations.png', tight_layout=True)
# Out:
# <ipython-input-102-4e9a6a83390e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mcorr = femaleHWDf.corr()
# <Axes: >

# %% [markdown]
# ## **Conculusion:**
#
# ### I conclude that this is all about how to use the matplotlib and seaborn to process, explore, and turn your data into an information. We are tasked to create use a real-world dataset and explore its contents/data using matplotlib and seaborn. This activity achieved the main objectives which are teaching us -- students to load the data, scatterplot graphs and correlatable variables, calculate the correlation using pythong, and last is to visualize our processed data better using seaborn.
#
#
# ## **Observations:**
#
# ### I have observed that some of the basic commands or concepts here are taught to us during our emerging technologies 1 course last-last semester. I also noticed that there are appropriate and organized way of showing the contents and proper way of coding to make it efficient and less hassle to read. I observed that I can easily recall the concepts but honestly need a refresher for this topic. This is an excellent crash course/laboratory activity for students like me.
